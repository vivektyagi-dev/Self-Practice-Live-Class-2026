# %% [markdown]
# ```mermaid
# graph LR
#     A[Request] --> B[before_agent] --> C[before_model] --> D[wrap_model_call]
#     D --> E[Model Call] --> F[after_model] --> G[wrap_tool_call] --> H[Tool Executes]
#     H --> I[after_agent] --> J[Response]
# ```

# %%
from langchain.agents.middleware import SummarizationMiddleware
