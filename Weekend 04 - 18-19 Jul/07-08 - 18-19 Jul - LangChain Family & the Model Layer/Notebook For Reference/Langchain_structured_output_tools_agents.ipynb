# %% [markdown]
# ```mermaid
# graph LR
#     A[Part 5: Structured Output] --> B[Part 6: Tools]
#     B --> C[Part 7: Agents]
#     A -.CineBot parses booking requests.-> D[One running example]
#     B -.CineBot checks showtimes, books seats.-> D
#     C -.CineBot ties it all into a real agent.-> D
# ```

# %% [markdown]
# ```mermaid
# graph TD
#     A[".with_structured_output(Schema)"] --> B{Does the provider have a NATIVE structured-output feature?}
#     B -->|Yes| C[ProviderStrategy<br/>uses the provider's own built-in feature]
#     B -->|No| D[ToolStrategy<br/>fakes it via a synthetic tool call]
#     C --> E[Fast, reliable, but ONLY works where supported]
#     D --> F[Works almost everywhere tool-calling works, slightly more overhead]
# ```
